# %% [markdown]
# # Setup

# %%
from imports import *
from utils import *

# %%
dump_path = './plots_and_results/'

# %% [markdown]
# # Urns

# %% [markdown]
# ## Cannonical
#
# - World States: Two binary variables X, Y
# - agents_observed_variables = $\{0:[0],1:[1]\}$
# - Random Cannonical Games
# - n_features = 2
# - n_signaling_actions = 2
# - n_final_actions = 4

# %%
# Load DataFrame from a CSV file
df_cannonical_urn = pd.read_csv(dump_path+'urnagent_results_cannonical.csv')
print(count_negative_nmi(dump_path+'urnagent_results_cannonical.csv'))
df_cannonical_urn.head(5)
# Out:
# {'Agent_0_Initial_NMI': 0, 'Agent_0_NMI': 0, 'Agent_1_Initial_NMI': 0, 'Agent_1_NMI': 0}
#    iteration  n_signaling_actions  n_final_actions  full_information
# 0          0                    2                4             False  \
# 1          0                    2                4             False
# 2          0                    2                4              True
# 3          0                    2                4              True
# 4          1                    2                4             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward
# 0         False                  NaN          NaN              0.4977  \
# 1          True             0.487675     0.259431              0.8653
# 2         False                  NaN          NaN              0.9907
# 3          True             0.502219     0.132554              0.9781
# 4         False                  NaN          NaN              0.4901
#
# ...

# %%
plot_all_histograms(df_cannonical_urn,bins=75,filename_prefix='Roth-Erev_cannonical')

# %%
plot_regression(df_cannonical_urn,'Agent_0_NMI','Agent_0_final_reward',filename_prefix='Roth-Erev_cannonical')
# Out:
# [Saved] ./plots_and_results/Roth-Erev_cannonical_regression_signals_True_fullinfo_True.png
# [Saved] ./plots_and_results/Roth-Erev_cannonical_regression_signals_True_fullinfo_False.png

# %% [markdown]
# ## Costly Signals

# %%
# Load DataFrame from a CSV file
df_cannonical_urn_costly = pd.read_csv(dump_path+'urnagent_results_cannonical_costly_signal.csv')
print(count_negative_nmi(dump_path+'urnagent_results_cannonical_costly_signal.csv'))
df_cannonical_urn_costly.head(5)
# Out:
# {'Agent_0_Initial_NMI': 0, 'Agent_0_NMI': 0, 'Agent_1_Initial_NMI': 0, 'Agent_1_NMI': 0}
#    iteration  n_signaling_actions  n_final_actions  full_information
# 0          0                    2                4             False  \
# 1          1                    2                4             False
# 2          2                    2                4             False
# 3          3                    2                4             False
# 4          4                    2                4             False
#
#    with_signals  Signal_Cost_A0  Signal_Cost_A1  Agent_0_Initial_NMI
# 0          True        0.245622        0.000574             0.272411  \
# 1          True        0.330696        0.439350             0.862824
# 2          True        0.248121        0.338037             0.700000
# 3          True        0.087521        0.283674             0.082943
# 4          True        0.309014        0.051113             0.119816
#
# ...

# %%
plot_reward_vs_cost(df_cannonical_urn_costly)
plot_nmi_vs_cost(df_cannonical_urn_costly)

# %%
plot_all_histograms(df_cannonical_urn_costly,bins=75,filename_prefix='Roth-Erev_cannonical_costly_signal')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# ...

# %% [markdown]
# ## General Urns
#
# - World States, n_features: Three binary variables X, Y, Z
# - agents_observed_variables = $\{0:[0,1],1:[1,2]\}$
# - n_signaling_actions = np.random.randint(2, 10)
# - n_final_actions = np.random.randint(2, 10)
# - Random Games

# %%
# Load DataFrame from a CSV file
df_urn = pd.read_csv(dump_path+'urnagent_results_complex_randomized.csv')
print(df_urn.shape)
print(count_negative_nmi(dump_path+'urnagent_results_complex_randomized.csv'))
df_urn.head(5)
# Out:
# (40000, 13)
# {'Agent_0_Initial_NMI': 0, 'Agent_0_NMI': 0, 'Agent_1_Initial_NMI': 0, 'Agent_1_NMI': 0}
#    iteration  n_signaling_actions  n_final_actions  full_information
# 0          0                    6                3             False  \
# 1          0                    6                3             False
# 2          0                    6                3              True
# 3          0                    6                3              True
# 4          1                    5                6             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward
# 0         False                  NaN          NaN              5.6461  \
# 1          True             0.505000     0.611149              5.9327
# 2         False                  NaN          NaN              6.3138
# 3          True             0.532828     0.442756              6.4891
# 4         False                  NaN          NaN              6.4161
#
# ...

# %%
plot_all_histograms(df_urn,bins=75,filename_prefix='Roth-Erev_complex_randomized')

# %%
plot_regression(df_urn,'Agent_0_NMI','Agent_0_final_reward',filename_prefix='Roth-Erev_complex_randomized')
# Out:
# [Saved] ./plots_and_results/Roth-Erev_complex_randomized_regression_signals_True_fullinfo_True.png
# [Saved] ./plots_and_results/Roth-Erev_complex_randomized_regression_signals_True_fullinfo_False.png

# %% [markdown]
# # Q-Learning

# %% [markdown]
# ## Cannonical
#
# - World States: Two binary variables X, Y
# - agents_observed_variables = $\{0:[0],1:[1]\}$
# - Random Cannonical Games
# - n_features = 2
# - n_signaling_actions = 2
# - n_final_actions = 4

# %%
# Load DataFrame from a CSV file
df_cannonical_qlearn = pd.read_csv(dump_path+'qlearning_results_cannonical.csv')
print(df_cannonical_qlearn.shape)
print(count_negative_nmi(dump_path+'qlearning_results_cannonical.csv'))
df_cannonical_qlearn.head(5)
# Out:
# (40000, 13)
# {'Agent_0_Initial_NMI': 0, 'Agent_0_NMI': 0, 'Agent_1_Initial_NMI': 0, 'Agent_1_NMI': 0}
#    iteration  n_signaling_actions  n_final_actions  full_information
# 0          0                    2                4             False  \
# 1          0                    2                4             False
# 2          0                    2                4              True
# 3          0                    2                4              True
# 4          1                    2                4             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward
# 0         False                  NaN          NaN              0.4939  \
# 1          True             0.146261     0.959148              0.9944
# 2         False                  NaN          NaN              0.9964
# 3          True             0.050861     0.470365              0.9937
# 4         False                  NaN          NaN              0.4938
#
# ...

# %%
plot_all_histograms(df_cannonical_qlearn,bins=75,filename_prefix='Q-learning_cannonical')
# Out:
# /Users/ignacio/Documents/VS Code/GitHub Repositories/RL_Signaling/utils.py:161: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# /Users/ignacio/Documents/VS Code/GitHub Repositories/RL_Signaling/utils.py:161: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(

# %%
# plot_payoff_comparison(df_cannonical_qlearn)
plot_regression(df_cannonical_qlearn,'Agent_0_NMI','Agent_0_final_reward',filename_prefix='Q-learning_cannonical')
# Out:
# [Saved] ./plots_and_results/Q-learning_cannonical_regression_signals_True_fullinfo_True.png
# [Saved] ./plots_and_results/Q-learning_cannonical_regression_signals_True_fullinfo_False.png

# %% [markdown]
# ## Costly Signals

# %%
# Load DataFrame from a CSV file
df_cannonical_ql_costly = pd.read_csv(dump_path+'qlearning_results_cannonical_costly_signal.csv')
print(count_negative_nmi(dump_path+'qlearning_results_cannonical_costly_signal.csv'))
df_cannonical_ql_costly.head(5)
# Out:
# {'Agent_0_Initial_NMI': 0, 'Agent_0_NMI': 0, 'Agent_1_Initial_NMI': 0, 'Agent_1_NMI': 0}
#    iteration  n_signaling_actions  n_final_actions  full_information
# 0          0                    2                4             False  \
# 1          1                    2                4             False
# 2          2                    2                4             False
# 3          3                    2                4             False
# 4          4                    2                4             False
#
#    with_signals  Signal_Cost_A0  Signal_Cost_A1  Agent_0_Initial_NMI
# 0          True        0.257270        0.257270             0.143609  \
# 1          True        0.413188        0.413188             0.143314
# 2          True        0.193087        0.193087             0.166579
# 3          True        0.218506        0.218506             0.110180
# 4          True        0.477620        0.477620             0.093407
#
# ...

# %%
plot_reward_vs_cost(df_cannonical_ql_costly)
plot_nmi_vs_cost(df_cannonical_ql_costly)

# %%
plot_all_histograms(df_cannonical_ql_costly,bins=75,filename_prefix='QLearning_cannonical_costly_signal')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/lib/histograms.py:906: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# ...

# %% [markdown]
# ## General Games
#
# - World States: Three binary variables X, Y, Z
# - agents_observed_variables = $\{0:[0,1],1:[1,2]\}$
# - n_features = 3
# - n_signaling_actions = np.random.randint(2, 10)
# - n_final_actions = np.random.randint(2, 10)
# - Random Games (possibly non-cannonical)

# %%
# Load DataFrame from a CSV file
df_qlearn = pd.read_csv(dump_path+'qlearning_results_complex_randomized.csv')
print(df_qlearn.shape)
print(count_negative_nmi(dump_path+'qlearning_results_complex_randomized.csv'))
df_qlearn.head(5)
# Out:
# (40000, 13)
# {'Agent_0_Initial_NMI': 0, 'Agent_0_NMI': 0, 'Agent_1_Initial_NMI': 0, 'Agent_1_NMI': 0}
#    iteration  n_signaling_actions  n_final_actions  full_information
# 0          0                    8                5             False  \
# 1          0                    8                5             False
# 2          0                    8                5              True
# 3          0                    8                5              True
# 4          1                    5                9             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward
# 0         False                  NaN          NaN              6.2359  \
# 1          True             0.169016     0.989208              7.2177
# 2         False                  NaN          NaN              7.4712
# 3          True             0.133752     0.424444              7.4575
# 4         False                  NaN          NaN              7.7441
#
# ...

# %%
plot_all_histograms(df_qlearn,bins=75,filename_prefix='Q-learning_complex_randomized')

# %%
plot_regression(df_qlearn,'Agent_0_NMI','Agent_0_final_reward',filename_prefix='Q-learning_complex_randomized')
# Out:
# [Saved] ./plots_and_results/Q-learning_complex_randomized_regression_signals_True_fullinfo_True.png
# [Saved] ./plots_and_results/Q-learning_complex_randomized_regression_signals_True_fullinfo_False.png

# %% [markdown]
# # TD Learning

# %% [markdown]
# ## Cannonical

# %%
# Load DataFrame from a CSV file
td_learning_results_cannonical = pd.read_csv(dump_path+'td_learning_results_cannonical.csv')
print(td_learning_results_cannonical.shape)
print(count_negative_nmi(dump_path+'td_learning_results_cannonical.csv'))
td_learning_results_cannonical.head(5)
# Out:
# (40000, 13)
# {'Agent_0_Initial_NMI': 0, 'Agent_0_NMI': 0, 'Agent_1_Initial_NMI': 0, 'Agent_1_NMI': 0}
#    iteration  n_signaling_actions  n_final_actions  full_information
# 0          0                    2                4             False  \
# 1          0                    2                4             False
# 2          0                    2                4              True
# 3          0                    2                4              True
# 4          1                    2                4             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward
# 0         False             0.050411     0.997248              0.4991  \
# 1          True             0.132376     0.992910              0.5039
# 2         False             0.024939     0.352184              0.7551
# 3          True             0.066443     0.403257              0.9981
# 4         False             0.220727     0.000023              0.4993
#
# ...

# %%
plot_all_histograms(td_learning_results_cannonical,bins=75,filename_prefix='TD-learning_cannonical')
# Out:
# /Users/ignacio/Documents/VS Code/GitHub Repositories/RL_Signaling/utils.py:161: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(

# %%
# plot_payoff_comparison(td_learning_results_cannonical)
plot_regression(td_learning_results_cannonical,'Agent_0_NMI','Agent_0_final_reward',filename_prefix='TD-learning_cannonical')
# Out:
# [Saved] ./plots_and_results/TD-learning_cannonical_regression_signals_True_fullinfo_True.png
# [Saved] ./plots_and_results/TD-learning_cannonical_regression_signals_True_fullinfo_False.png

# %% [markdown]
# ## General Games
#
# - World States: Three binary variables X, Y, Z
# - agents_observed_variables = $\{0:[0,1],1:[1,2]\}$
# - n_features = 3
# - n_signaling_actions = np.random.randint(2, 10)
# - n_final_actions = np.random.randint(2, 10)
# - Random Games (possibly non-cannonical)

# %%
# Load DataFrame from a CSV file
td_learning_complex = pd.read_csv(dump_path+'td_learning_results_complex_randomized.csv')
print(td_learning_complex.shape)
print(count_negative_nmi(dump_path+'td_learning_results_complex_randomized.csv'))
td_learning_complex.head(5)
# Out:
# (40000, 13)
# {'Agent_0_Initial_NMI': 0, 'Agent_0_NMI': 0, 'Agent_1_Initial_NMI': 0, 'Agent_1_NMI': 0}
#    iteration  n_signaling_actions  n_final_actions  full_information
# 0          0                    2                2             False  \
# 1          0                    2                2             False
# 2          0                    2                2              True
# 3          0                    2                2              True
# 4          1                    4                3             False
#
#    with_signals  Agent_0_Initial_NMI   Agent_0_NMI  Agent_0_avg_reward
# 0         False             0.203567  2.053765e-05              3.9828  \
# 1          True             0.058918  4.973934e-01              6.3703
# 2         False             0.129808  2.715508e-01              3.9828
# 3          True             0.129808  1.982824e-07              6.3735
# 4         False             0.118772  4.215468e-01              4.3553
#
# ...

# %%
plot_all_histograms(td_learning_complex,bins=75,filename_prefix='TD-learning_complex_randomized')

# %%
plot_regression(td_learning_complex,'Agent_0_NMI','Agent_0_final_reward',filename_prefix='Q-learning_complex_randomized')
# Out:
# [Saved] ./plots_and_results/Q-learning_complex_randomized_regression_signals_True_fullinfo_True.png
# [Saved] ./plots_and_results/Q-learning_complex_randomized_regression_signals_True_fullinfo_False.png
