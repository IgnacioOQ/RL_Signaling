# %% [markdown]
# # Load Data

# %%
from imports import *
from utils import *

# %%
# Load DataFrame from a CSV file
df_cannonical_urn = pd.read_csv('basic_urn_results_cannonical.csv')
df_cannonical_urn.head(5)
# Out:
#    iteration  n_signaling_actions  n_final_actions  full_information  \
# 0          0                    2                4             False
# 1          0                    2                4             False
# 2          0                    2                4              True
# 3          0                    2                4              True
# 4          1                    2                4             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward  \
# 0         False             0.539748     0.000070              0.4972
# 1          True             0.208951     0.236912              0.4974
# 2         False             0.094677     0.000028              0.9930
# 3          True             0.581122     0.095458              0.9809
# 4         False             0.213916     0.000020              0.4986
#
#    Agent_0_final_reward  Agent_1_Initial_NMI  Agent_1_NMI  Agent_1_avg_reward  \
# 0                  0.50             0.039804     0.000044              0.4964
# 1                  0.56             0.363530     0.005763              0.7505
# 2                  1.00             0.220529     0.000051              0.9910
# 3                  1.00             0.335676     0.022189              0.9829
# 4                  0.47             0.057184     0.000019              0.4944
#
#    Agent_1_final_reward
# 0                  0.53
# 1                  0.75
# 2                  1.00
# 3                  1.00
# 4                  0.57

# %%
# Load DataFrame from a CSV file
df_urn = pd.read_csv('urn_results.csv')
df_urn.head(5)
# Out:
#    iteration  n_signaling_actions  n_final_actions  full_information  \
# 0          0                    4                8             False
# 1          0                    4                8             False
# 2          0                    4                8              True
# 3          0                    4                8              True
# 4          1                    4                8             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward  \
# 0         False             0.307822     0.000211              6.0797
# 1          True             0.631698     0.528630              6.9803
# 2         False             0.514702     0.000593              7.1942
# 3          True             0.505158     0.437837              7.3024
# 4         False             0.397418     0.000282              5.8622
#
#    Agent_0_final_reward  Agent_1_Initial_NMI  Agent_1_NMI  Agent_1_avg_reward  \
# 0                  6.21             0.589472     0.000466              7.3156
# 1                  7.42             0.726823     0.511932              6.8125
# 2                  7.06             0.653258     0.000606              7.2721
# 3                  7.30             0.369230     0.344170              7.4223
# 4                  6.11             0.542990     0.000223              6.3086
#
#    Agent_1_final_reward
# 0                  7.48
# 1                  7.00
# 2                  7.48
# 3                  7.55
# 4                  6.12

# %% [markdown]
# # Cannonical
#
# - World States: Two binary variables X, Y
# - agents_observed_variables = {0:[0],1:[1]}
# - Random Cannonical Games
# - n_features = 2
# - n_signaling_actions = 2
# - n_final_actions = 4

# %%
plot_all_histograms(df_cannonical_urn,bins=75)

# %%
plot_payoff_comparison(df_cannonical_urn)

# %% [markdown]
# # General Urns
#
# - World States: Three binary variables X, Y, Z
# - agents_observed_variables = {0:[0,1],1:[1,2]}
# - n_features = 3 #parameters['n_features']
# - n_signaling_actions = 4 #parameters['n_signaling_actions']
# - n_final_actions = 8 #parameters['n_final_actions']
# - Random Games (possibly non-cannonical)

# %% [markdown]
# plot_all_histograms(df_urn,bins=75)

# %%
plot_payoff_comparison(df_urn)
