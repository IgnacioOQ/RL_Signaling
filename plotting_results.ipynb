# %% [markdown]
# # Load Data

# %%
from imports import *
from utils import *
import seaborn as sns

# %%
# Load DataFrame from a CSV file
df_cannonical_urn = pd.read_csv('basic_urn_results_cannonical.csv')
df_cannonical_urn.head(5)
# Out:
#    iteration  n_signaling_actions  n_final_actions  full_information  \
# 0          0                    2                4             False
# 1          0                    2                4             False
# 2          0                    2                4              True
# 3          0                    2                4              True
# 4          1                    2                4             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward  \
# 0         False             0.148080     0.000014               0.470
# 1          True             0.036997     0.023066               0.793
# 2         False             0.308568     0.000280               0.931
# 3          True             0.390306     0.010462               0.872
# 4         False             0.066439     0.000012               0.471
#
#    Agent_0_final_reward  Agent_1_Initial_NMI  Agent_1_NMI  Agent_1_avg_reward  \
# 0                  0.46             0.065636     0.000224               0.486
# 1                  0.86             0.061523     0.545604               0.476
# 2                  0.99             0.058895     0.000832               0.926
# 3                  0.98             0.416241     0.172310               0.855
# 4                  0.42             0.016745     0.000159               0.460
#
#    Agent_1_final_reward
# 0                  0.55
# 1                  0.57
# 2                  0.98
# 3                  0.98
# 4                  0.50

# %%
# Load DataFrame from a CSV file
df_urn = pd.read_csv('urn_results.csv')
df_urn.head(5)
# Out:
#    iteration  n_signaling_actions  n_final_actions  full_information  \
# 0          0                    4                8             False
# 1          0                    4                8             False
# 2          0                    4                8              True
# 3          0                    4                8              True
# 4          1                    4                8             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward  \
# 0         False             0.225179     0.104179                6.30
# 1          True             0.306240     0.306373                6.57
# 2         False             0.520978     0.199609                5.64
# 3          True             0.357319     0.424079                5.93
# 4         False             0.495720     0.142018                6.10
#
#    Agent_0_final_reward  Agent_1_Initial_NMI  Agent_1_NMI  Agent_1_avg_reward  \
# 0                  6.30             0.500508     0.176293                4.95
# 1                  6.57             0.517458     0.560884                6.07
# 2                  5.64             0.351840     0.135004                6.09
# 3                  5.93             0.763978     0.479776                6.44
# 4                  6.10             0.619974     0.165041                5.81
#
#    Agent_1_final_reward
# 0                  4.95
# 1                  6.07
# 2                  6.09
# 3                  6.44
# 4                  5.81

# %% [markdown]
# # Cannonical
#
# - World States: Two binary variables X, Y
# - agents_observed_variables = {0:[0],1:[1]}
# - Random Cannonical Games
# - n_features = 2
# - n_signaling_actions = 2
# - n_final_actions = 4

# %%
plot_all_histograms(df_cannonical_urn,bins=75)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 plot_all_histograms(df_cannonical_urn,bins=75)
#
# File ~/GitRepositories/RL_Signaling/utils.py:181, in plot_all_histograms(df, bins)
#     180 def plot_all_histograms(df,bins=75):
# --> 181     plot_histograms_with_kde(df,'Agent_0_final_reward',bins=75)
#     182     plot_histograms_with_kde(df,'Agent_0_avg_reward',bins=75)
#     183     plot_histograms_with_kde(df,'Agent_1_final_reward',bins=75)
#
# File ~/GitRepositories/RL_Signaling/utils.py:145, in plot_histograms_with_kde(df, variable, bins, figsize, alpha, kde, variables)
#     143  # Plot KDE curve if enabled
#     144  if kde:
# --> 145      sns.kdeplot(
#     146          subset_df[variable],
#     147          color=colors[idx],
#     148          linewidth=2#,
#     149          #label=f'KDE: signals={with_signals}, full_infon={full_information}'
#     150      )
#     152 # Add a vertical line for the mean
#     153  mean_value = subset_df[variable].mean()
#
# NameError: name 'sns' is not defined

# %%
plot_payoff_comparison(df_cannonical_urn)

# %% [markdown]
# # General Urns
#
# - World States: Three binary variables X, Y, Z
# - agents_observed_variables = {0:[0,1],1:[1,2]}
# - n_features = 3 #parameters['n_features']
# - n_signaling_actions = 4 #parameters['n_signaling_actions']
# - n_final_actions = 8 #parameters['n_final_actions']
# - Random Games (possibly non-cannonical)

# %% [markdown]
# plot_all_histograms(df_urn,bins=75)

# %%
plot_payoff_comparison(df_urn)
