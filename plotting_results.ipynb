# %% [markdown]
# # Setup

# %%
from imports import *
from utils import *

# %%
dump_path = './plots_and_results/'

# %% [markdown]
# # Urns

# %% [markdown]
# ## Cannonical
#
# - World States: Two binary variables X, Y
# - agents_observed_variables = $\{0:[0],1:[1]\}$
# - Random Cannonical Games
# - n_features = 2
# - n_signaling_actions = 2
# - n_final_actions = 4

# %%
# Load DataFrame from a CSV file
df_cannonical_urn = pd.read_csv(dump_path+'urnagent_results_cannonical.csv')
print(count_negative_nmi(dump_path+'urnagent_results_cannonical.csv'))
df_cannonical_urn.head(5)
# Out:
# {'Agent_0_Initial_NMI': 0, 'Agent_0_NMI': 0, 'Agent_1_Initial_NMI': 0, 'Agent_1_NMI': 0}
#    iteration  n_signaling_actions  n_final_actions  full_information
# 0          0                    2                4             False  \
# 1          0                    2                4             False
# 2          0                    2                4              True
# 3          0                    2                4              True
# 4          1                    2                4             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward
# 0         False                  NaN          NaN              0.4977  \
# 1          True             0.487675     0.259431              0.8653
# 2         False                  NaN          NaN              0.9907
# 3          True             0.502219     0.132554              0.9781
# 4         False                  NaN          NaN              0.4901
#
# ...

# %%
plot_basecase_kde(df_cannonical_urn,'Agent_0_NMI',bins=75)
plot_basecase_kde(df_cannonical_urn,'Agent_0_final_reward',bins=75)
# plot_basecase_kde(df_cannonical_urn,'Agent_1_NMI',bins=75)

# %%
plot_all_histograms(df_cannonical_urn,bins=75)

# %%
plot_regression(df_cannonical_urn,'Agent_0_NMI','Agent_0_final_reward')

# %% [markdown]
# ## General Urns
#
# - World States: Three binary variables X, Y, Z
# - agents_observed_variables = $\{0:[0,1],1:[1,2]\}$
# - n_features = 3 #parameters['n_features']
# - n_signaling_actions = 4 #parameters['n_signaling_actions']
# - n_final_actions = 8 #parameters['n_final_actions']
# - Random Games (possibly non-cannonical)

# %%
# Load DataFrame from a CSV file
df_urn = pd.read_csv(dump_path+'urnagent_results_complex_randomized.csv')
print(df_urn.shape)
print(count_negative_nmi(dump_path+'urnagent_results_complex_randomized.csv'))
df_urn.head(5)
# Out:
# (8000, 13)
# {'Agent_0_Initial_NMI': 0, 'Agent_0_NMI': 0, 'Agent_1_Initial_NMI': 0, 'Agent_1_NMI': 0}
#    iteration  n_signaling_actions  n_final_actions  full_information
# 0          0                    6                3             False  \
# 1          0                    6                3             False
# 2          0                    6                3              True
# 3          0                    6                3              True
# 4          1                    5                6             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward
# 0         False                  NaN          NaN              5.6461  \
# 1          True             0.505000     0.611149              5.9327
# 2         False                  NaN          NaN              6.3138
# 3          True             0.532828     0.442756              6.4891
# 4         False                  NaN          NaN              6.4161
#
# ...

# %%
plot_basecase_kde(df_urn,'Agent_0_NMI',bins=75)
# plot_basecase_kde(df_cannonical_urn,'Agent_1_NMI',bins=75)

# %%
plot_basecase_kde(df_urn,'Agent_0_final_reward',bins=75)

# %%
plot_all_histograms(df_urn,bins=75)

# %%
# plot_payoff_comparison(df_urn)

# %%
plot_regression(df_urn,'Agent_0_NMI','Agent_0_final_reward')

# %% [markdown]
# # Q-Learning

# %% [markdown]
# ## Load Data

# %%
# # Load DataFrame from a CSV file
# df_qlearn = pd.read_csv('qlearning_results_bigexplore.csv')
# print(df_qlearn.shape)
# print(count_negative_nmi('qlearning_results_bigexplore.csv'))
# df_qlearn.head(5)

# %% [markdown]
# ## Cannonical
#
# - World States: Two binary variables X, Y
# - agents_observed_variables = $\{0:[0],1:[1]\}$
# - Random Cannonical Games
# - n_features = 2
# - n_signaling_actions = 2
# - n_final_actions = 4

# %%
# Load DataFrame from a CSV file
df_cannonical_qlearn = pd.read_csv(dump_path+'qlearning_results_cannonical.csv')
print(df_cannonical_qlearn.shape)
print(count_negative_nmi(dump_path+'qlearning_results_cannonical.csv'))
df_cannonical_qlearn.head(5)
# Out:
# (40000, 13)
# {'Agent_0_Initial_NMI': 0, 'Agent_0_NMI': 0, 'Agent_1_Initial_NMI': 0, 'Agent_1_NMI': 0}
#    iteration  n_signaling_actions  n_final_actions  full_information
# 0          0                    2                4             False  \
# 1          0                    2                4             False
# 2          0                    2                4              True
# 3          0                    2                4              True
# 4          1                    2                4             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward
# 0         False                  NaN          NaN              0.4939  \
# 1          True             0.146261     0.959148              0.9944
# 2         False                  NaN          NaN              0.9964
# 3          True             0.050861     0.470365              0.9937
# 4         False                  NaN          NaN              0.4938
#
# ...

# %%
plot_basecase_kde(df_cannonical_qlearn,'Agent_0_NMI',bins=75)
plot_basecase_kde(df_cannonical_qlearn,'Agent_0_final_reward',bins=75)

# %%
plot_all_histograms(df_cannonical_qlearn,bins=75)
# Out:
# /Users/ignacio/Documents/VS Code/GitHub Repositories/RL_Signaling/utils.py:159: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# /Users/ignacio/Documents/VS Code/GitHub Repositories/RL_Signaling/utils.py:159: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# /Users/ignacio/Documents/VS Code/GitHub Repositories/RL_Signaling/utils.py:159: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# /Users/ignacio/Documents/VS Code/GitHub Repositories/RL_Signaling/utils.py:159: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(

# %%
# plot_payoff_comparison(df_cannonical_qlearn)
plot_regression(df_cannonical_qlearn,'Agent_0_NMI','Agent_0_final_reward')

# %% [markdown]
# ## General Games
#
# - World States: Three binary variables X, Y, Z
# - agents_observed_variables = $\{0:[0,1],1:[1,2]\}$
# - n_features = 3 #parameters['n_features']
# - n_signaling_actions = 4 #parameters['n_signaling_actions']
# - n_final_actions = 8 #parameters['n_final_actions']
# - Random Games (possibly non-cannonical)

# %%
# Load DataFrame from a CSV file
df_qlearn = pd.read_csv(dump_path+'qlearning_results_complex.csv')
print(df_qlearn.shape)
print(count_negative_nmi(dump_path+'qlearning_results_complex.csv'))
df_qlearn.head(5)
# Out:
# (8000, 13)
# {'Agent_0_Initial_NMI': 0, 'Agent_0_NMI': 0, 'Agent_1_Initial_NMI': 0, 'Agent_1_NMI': 0}
#    iteration  n_signaling_actions  n_final_actions  full_information
# 0          0                    4                8             False  \
# 1          0                    4                8             False
# 2          0                    4                8              True
# 3          0                    4                8              True
# 4          1                    4                8             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward
# 0         False                  NaN          NaN              7.1399  \
# 1          True             0.149632     0.984859              8.0894
# 2         False                  NaN          NaN              8.2247
# 3          True             0.133752     0.421642              8.2131
# 4         False                  NaN          NaN              5.7550
#
# ...

# %%
plot_basecase_kde(df_qlearn,'Agent_0_NMI',bins=75)
plot_basecase_kde(df_qlearn,'Agent_0_final_reward',bins=75)

# %%
plot_all_histograms(df_qlearn,bins=75)

# %%
# plot_payoff_comparison(df_qlearn)
plot_regression(df_qlearn,'Agent_0_NMI','Agent_0_final_reward')

# %% [markdown]
# # TD Learning

# %% [markdown]
# ## Cannonical

# %%
# Load DataFrame from a CSV file
td_learning_results_cannonical = pd.read_csv(dump_path+'td_learning_results_cannonical.csv')
print(td_learning_results_cannonical.shape)
print(count_negative_nmi(dump_path+'td_learning_results_cannonical.csv'))
td_learning_results_cannonical.head(5)
# Out:
# (40000, 13)
# {'Agent_0_Initial_NMI': 0, 'Agent_0_NMI': 0, 'Agent_1_Initial_NMI': 0, 'Agent_1_NMI': 0}
#    iteration  n_signaling_actions  n_final_actions  full_information
# 0          0                    2                4             False  \
# 1          0                    2                4             False
# 2          0                    2                4              True
# 3          0                    2                4              True
# 4          1                    2                4             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward
# 0         False             0.050411     0.997248              0.4991  \
# 1          True             0.132376     0.992910              0.5039
# 2         False             0.024939     0.352184              0.7551
# 3          True             0.066443     0.403257              0.9981
# 4         False             0.220727     0.000023              0.4993
#
# ...

# %%
plot_basecase_kde(td_learning_results_cannonical,'Agent_0_NMI',bins=75)
plot_basecase_kde(td_learning_results_cannonical,'Agent_0_final_reward',bins=75)

# %%
plot_all_histograms(td_learning_results_cannonical,bins=75)
# Out:
# /Users/ignacio/Documents/VS Code/GitHub Repositories/RL_Signaling/utils.py:159: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# /Users/ignacio/Documents/VS Code/GitHub Repositories/RL_Signaling/utils.py:159: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(

# %%
# plot_payoff_comparison(td_learning_results_cannonical)
plot_regression(td_learning_results_cannonical,'Agent_0_NMI','Agent_0_final_reward')

# %% [markdown]
# ## Complex

# %%
# Load DataFrame from a CSV file
td_learning = pd.read_csv(dump_path+'td_learning_results_complex.csv')
print(td_learning.shape)
print(count_negative_nmi(dump_path+'td_learning_results_complex.csv'))
td_learning.head(5)
# Out:
# (8000, 13)
# {'Agent_0_Initial_NMI': 0, 'Agent_0_NMI': 0, 'Agent_1_Initial_NMI': 0, 'Agent_1_NMI': 0}
#    iteration  n_signaling_actions  n_final_actions  full_information
# 0          0                    4                8             False  \
# 1          0                    4                8             False
# 2          0                    4                8              True
# 3          0                    4                8              True
# 4          1                    4                8             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward
# 0         False             0.366711     0.500053              5.1248  \
# 1          True             0.366711     0.498183              5.9277
# 2         False             0.366711     0.633229              6.3112
# 3          True             0.366711     0.467865              6.3744
# 4         False             0.590856     0.997450              5.2516
#
# ...

# %%
plot_basecase_kde(td_learning,'Agent_0_NMI',bins=75)
plot_basecase_kde(td_learning,'Agent_0_final_reward',bins=75)

# %%
plot_all_histograms(td_learning,bins=75)

# %%
plot_regression(td_learning,'Agent_0_NMI','Agent_0_final_reward')
