# %% [markdown]
# # Setup

# %%
from imports import *
from utils import *

# %% [markdown]
# # Urns

# %% [markdown]
# ## Load Data

# %%
# Load DataFrame from a CSV file
df_cannonical_urn = pd.read_csv('urnagent_results_cannonical.csv')
print(count_negative_nmi('urnagent_results_cannonical.csv'))
df_cannonical_urn.head(5)
# Out:
# {'Agent_0_Initial_NMI': 0, 'Agent_0_NMI': 0, 'Agent_1_Initial_NMI': 0, 'Agent_1_NMI': 0}
#    iteration  n_signaling_actions  n_final_actions  full_information
# 0          0                    2                4             False  \
# 1          0                    2                4             False
# 2          0                    2                4              True
# 3          0                    2                4              True
# 4          1                    2                4             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward
# 0         False             0.057641     0.025546              0.4920  \
# 1          True             0.480986     0.009727              0.5535
# 2         False             0.221660     0.169591              0.9878
# 3          True             0.375987     0.151510              0.9810
# 4         False             0.100402     0.323732              0.4908
#
#    Agent_0_final_reward  Agent_1_Initial_NMI  Agent_1_NMI  Agent_1_avg_reward
# 0                  0.56             0.173576     0.075992              0.4942  \
# 1                  0.60             0.138482     0.043955              0.5268
# 2                  0.99             0.104891     0.067951              0.9927
# 3                  1.00             0.246424     0.115551              0.9812
# 4                  0.47             0.122331     0.150537              0.4972
#
#    Agent_1_final_reward
# 0                  0.47
# 1                  0.51
# 2                  1.00
# 3                  1.00
# 4                  0.56

# %%
# Load DataFrame from a CSV file
df_urn = pd.read_csv('urn_results.csv')
print(df_urn.shape)
print(count_negative_nmi('urn_results.csv'))
df_urn.head(5)
# Out:
# (4000, 13)
# {'Agent_0_Initial_NMI': 0, 'Agent_0_NMI': 0, 'Agent_1_Initial_NMI': 0, 'Agent_1_NMI': 0}
#    iteration  n_signaling_actions  n_final_actions  full_information
# 0          0                    4                8             False  \
# 1          0                    4                8             False
# 2          0                    4                8              True
# 3          0                    4                8              True
# 4          0                    4                8             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward
# 0         False             0.700000     0.565434              5.1759  \
# 1          True             0.800000     0.526946              7.1400
# 2         False             0.509319     0.339544              6.6929
# 3          True             0.526595     0.394283              6.8767
# 4         False             0.737178     0.515397              4.9213
#
#    Agent_0_final_reward  Agent_1_Initial_NMI  Agent_1_NMI  Agent_1_avg_reward
# 0                  5.14             0.344627     0.402441              6.4209  \
# 1                  7.57             0.534893     0.401957              7.1820
# 2                  6.80             0.637160     0.487189              7.2947
# 3                  7.15             0.680643     0.429285              7.3710
# 4                  5.22             0.231137     0.299093              5.8677
#
#    Agent_1_final_reward
# 0                  6.81
# 1                  7.39
# 2                  7.24
# 3                  7.49
# 4                  5.83

# %% [markdown]
# ## Cannonical
#
# - World States: Two binary variables X, Y
# - agents_observed_variables = $\{0:[0],1:[1]\}$
# - Random Cannonical Games
# - n_features = 2
# - n_signaling_actions = 2
# - n_final_actions = 4

# %%
plot_basecase_kde(df_cannonical_urn,'Agent_0_NMI',bins=75)
# plot_basecase_kde(df_cannonical_urn,'Agent_1_NMI',bins=75)

# %%
plot_basecase_kde(df_cannonical_urn,'Agent_0_final_reward',bins=75)

# %%
plot_all_histograms(df_cannonical_urn,bins=75)

# %%
plot_payoff_comparison(df_cannonical_urn)

# %% [markdown]
# ## General Urns
#
# - World States: Three binary variables X, Y, Z
# - agents_observed_variables = $\{0:[0,1],1:[1,2]\}$
# - n_features = 3 #parameters['n_features']
# - n_signaling_actions = 4 #parameters['n_signaling_actions']
# - n_final_actions = 8 #parameters['n_final_actions']
# - Random Games (possibly non-cannonical)

# %%
plot_basecase_kde(df_urn,'Agent_0_NMI',bins=75)
# plot_basecase_kde(df_cannonical_urn,'Agent_1_NMI',bins=75)

# %%
plot_basecase_kde(df_urn,'Agent_0_final_reward',bins=75)

# %%
plot_all_histograms(df_urn,bins=75)

# %%
plot_payoff_comparison(df_urn)

# %% [markdown]
# # Q-Learning initial_epsilon=1

# %% [markdown]
# ## Load Data

# %%
# Load DataFrame from a CSV file
df_cannonical_qlearn = pd.read_csv('basic_qlearning_results_cannonical_bigexplore.csv')
print(df_cannonical_qlearn.shape)
print(count_negative_nmi('basic_qlearning_results_cannonical_bigexplore.csv'))
df_cannonical_qlearn.head(5)
# Out:
# (4000, 13)
# {'Agent_0_Initial_NMI': 0, 'Agent_0_NMI': 0, 'Agent_1_Initial_NMI': 0, 'Agent_1_NMI': 0}
#    iteration  n_signaling_actions  n_final_actions  full_information  \
# 0          0                    2                4             False
# 1          0                    2                4             False
# 2          0                    2                4              True
# 3          0                    2                4              True
# 4          0                    2                4             False
#
#    with_signals  Agent_0_Initial_NMI   Agent_0_NMI  Agent_0_avg_reward  \
# 0         False             0.570894  9.116480e-01              0.5007
# 1          True             0.179164  8.982889e-01              0.5043
# 2         False             0.387778  3.624139e-01              0.9843
# 3          True             0.176686  4.500545e-01              0.9836
# 4         False             0.234946  1.309802e-07              0.4839
#
#    Agent_0_final_reward  Agent_1_Initial_NMI   Agent_1_NMI  \
# 0                  0.54             0.036574  9.079242e-01
# 1                  0.46             0.204742  6.144013e-07
# 2                  1.00             0.115182  3.722522e-01
# 3                  1.00             0.163430  3.642563e-01
# 4                  0.43             0.151671  8.934885e-01
#
#    Agent_1_avg_reward  Agent_1_final_reward
# 0              0.4999                  0.54
# 1              0.9767                  1.00
# 2              0.9844                  1.00
# 3              0.9826                  1.00
# 4              0.4821                  0.43

# %%
# Load DataFrame from a CSV file
df_qlearn = pd.read_csv('qlearning_results_bigexplore.csv')
print(df_qlearn.shape)
print(count_negative_nmi('qlearning_results_bigexplore.csv'))
df_qlearn.head(5)
# Out:
# (2000, 13)
# {'Agent_0_Initial_NMI': 0, 'Agent_0_NMI': 0, 'Agent_1_Initial_NMI': 0, 'Agent_1_NMI': 0}
#    iteration  n_signaling_actions  n_final_actions  full_information  \
# 0          0                    4                8             False
# 1          0                    4                8             False
# 2          0                    4                8              True
# 3          0                    4                8              True
# 4          0                    4                8             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward  \
# 0         False             0.247118     0.696237              7.6814
# 1          True             0.132412     0.666911              7.3895
# 2         False             0.519695     0.435428              8.4204
# 3          True             0.439390     0.552910              8.3696
# 4         False             0.296271     0.371602              7.0715
#
#    Agent_0_final_reward  Agent_1_Initial_NMI  Agent_1_NMI  Agent_1_avg_reward  \
# 0                  7.92             0.288788     0.681435              7.5635
# 1                  7.62             0.296992     0.693844              7.8924
# 2                  8.48             0.604219     0.552274              8.6735
# 3                  8.51             0.354849     0.570991              8.6089
# 4                  7.09             0.466024     0.695794              7.8211
#
#    Agent_1_final_reward
# 0                  7.66
# 1                  8.06
# 2                  8.75
# 3                  8.69
# 4                  7.98

# %% [markdown]
# ## Cannonical
#
# - World States: Two binary variables X, Y
# - agents_observed_variables = $\{0:[0],1:[1]\}$
# - Random Cannonical Games
# - n_features = 2
# - n_signaling_actions = 2
# - n_final_actions = 4

# %%
plot_basecase_kde(df_cannonical_qlearn,'Agent_0_NMI',bins=75)
# plot_basecase_kde(df_cannonical_urn,'Agent_1_NMI',bins=75)

# %%
plot_basecase_kde(df_cannonical_qlearn,'Agent_0_final_reward',bins=75)

# %%
plot_all_histograms(df_cannonical_qlearn,bins=75)

# %%
plot_payoff_comparison(df_cannonical_qlearn)

# %% [markdown]
# ## General Games
#
# - World States: Three binary variables X, Y, Z
# - agents_observed_variables = $\{0:[0,1],1:[1,2]\}$
# - n_features = 3 #parameters['n_features']
# - n_signaling_actions = 4 #parameters['n_signaling_actions']
# - n_final_actions = 8 #parameters['n_final_actions']
# - Random Games (possibly non-cannonical)

# %%
plot_basecase_kde(df_qlearn,'Agent_0_NMI',bins=75)
# plot_basecase_kde(df_cannonical_urn,'Agent_1_NMI',bins=75)

# %%
plot_basecase_kde(df_qlearn,'Agent_0_final_reward',bins=75)

# %%
plot_all_histograms(df_qlearn,bins=75)

# %%
plot_payoff_comparison(df_qlearn)
