# %% [markdown]
# # Setup

# %%
from imports import *
from utils import *

# %% [markdown]
# # Urns

# %% [markdown]
# ## Load Data

# %%
# Load DataFrame from a CSV file
df_cannonical_urn = pd.read_csv('basic_urn_results_cannonical.csv')
df_cannonical_urn.head(5)
# Out:
#    iteration  n_signaling_actions  n_final_actions  full_information  \
# 0          0                    2                4             False
# 1          0                    2                4             False
# 2          0                    2                4              True
# 3          0                    2                4              True
# 4          1                    2                4             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward  \
# 0         False             0.092475     0.000042              0.4877
# 1          True             0.038322     0.247270              0.5475
# 2         False             0.167234     0.000120              0.9903
# 3          True             0.364947     0.101340              0.9847
# 4         False             0.110125     0.000002              0.5028
#
#    Agent_0_final_reward  Agent_1_Initial_NMI   Agent_1_NMI  \
# 0                  0.55             0.196849  1.773301e-07
# 1                  0.60             0.037954  6.770783e-02
# 2                  1.00             0.260113  1.120961e-05
# 3                  0.99             0.405309  4.009917e-02
# 4                  0.46             0.209403  3.904812e-05
#
#    Agent_1_avg_reward  Agent_1_final_reward
# 0              0.4872                  0.53
# 1              0.7525                  0.75
# 2              0.9911                  1.00
# 3              0.9813                  0.98
# 4              0.4995                  0.48

# %%
# Load DataFrame from a CSV file
df_urn = pd.read_csv('urn_results.csv')
df_urn.head(5)
# Out:
#    iteration  n_signaling_actions  n_final_actions  full_information  \
# 0          0                    4                8             False
# 1          0                    4                8             False
# 2          0                    4                8              True
# 3          0                    4                8              True
# 4          1                    4                8             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward  \
# 0         False             0.597363     0.000443              6.6281
# 1          True             0.387968     0.562594              7.3525
# 2         False             0.559228     0.000323              7.6612
# 3          True             0.565112     0.395179              7.1722
# 4         False             0.350235     0.000226              5.3963
#
#    Agent_0_final_reward  Agent_1_Initial_NMI  Agent_1_NMI  Agent_1_avg_reward  \
# 0                  6.73             0.513306     0.000557              5.7533
# 1                  7.51             0.549503     0.191165              5.8660
# 2                  7.78             0.373326     0.000524              6.9018
# 3                  7.47             0.499712     0.374766              7.1991
# 4                  4.96             0.440143     0.000655              6.3446
#
#    Agent_1_final_reward
# 0                  6.42
# 1                  6.54
# 2                  7.02
# 3                  7.62
# 4                  6.32

# %% [markdown]
# ## Cannonical
#
# - World States: Two binary variables X, Y
# - agents_observed_variables = {0:[0],1:[1]}
# - Random Cannonical Games
# - n_features = 2
# - n_signaling_actions = 2
# - n_final_actions = 4

# %%
plot_all_histograms(df_cannonical_urn,bins=75)

# %%
plot_payoff_comparison(df_cannonical_urn)

# %% [markdown]
# ## General Urns
#
# - World States: Three binary variables X, Y, Z
# - agents_observed_variables = {0:[0,1],1:[1,2]}
# - n_features = 3 #parameters['n_features']
# - n_signaling_actions = 4 #parameters['n_signaling_actions']
# - n_final_actions = 8 #parameters['n_final_actions']
# - Random Games (possibly non-cannonical)

# %%
plot_all_histograms(df_urn,bins=75)

# %%
plot_payoff_comparison(df_urn)

# %% [markdown]
# # Q-Learning initial_epsilon=0.2

# %% [markdown]
# ## Load Data

# %%
# Load DataFrame from a CSV file
df_cannonical_qlearn = pd.read_csv('basic_qlearning_results_cannonical.csv')
df_cannonical_qlearn.head(5)
# Out:
#    iteration  n_signaling_actions  n_final_actions  full_information  \
# 0          0                    2                4             False
# 1          0                    2                4             False
# 2          0                    2                4              True
# 3          0                    2                4              True
# 4          1                    2                4             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward  \
# 0         False             0.000000     0.000055              0.4913
# 1          True             0.025201     0.000042              0.4979
# 2         False             0.057959     0.000036              0.9930
# 3          True             0.000000     0.370937              0.9415
# 4         False             0.096984     0.000003              0.4963
#
#    Agent_0_final_reward  Agent_1_Initial_NMI   Agent_1_NMI  \
# 0                  0.49             0.107919  1.984549e-04
# 1                  0.49             0.027882  8.297172e-04
# 2                  1.00             0.020244  2.423699e-04
# 3                  0.96             0.000000  3.842607e-01
# 4                  0.52             0.130858  1.746946e-07
#
#    Agent_1_avg_reward  Agent_1_final_reward
# 0              0.4919                  0.49
# 1              0.4973                  0.48
# 2              0.9245                  1.00
# 3              0.7580                  0.79
# 4              0.4915                  0.44

# %%
# Load DataFrame from a CSV file
df_qlearn = pd.read_csv('qlearning_results.csv')
df_qlearn.head(5)
# Out:
#    iteration  n_signaling_actions  n_final_actions  full_information  \
# 0          0                    4                8             False
# 1          0                    4                8             False
# 2          0                    4                8              True
# 3          0                    4                8              True
# 4          1                    4                8             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward  \
# 0         False             0.678373     0.000425              6.6836
# 1          True             0.232010     0.471791              5.9654
# 2         False             0.132208     0.000393              7.9209
# 3          True             0.267045     0.463005              5.9425
# 4         False             0.126335     0.000199              7.1771
#
#    Agent_0_final_reward  Agent_1_Initial_NMI  Agent_1_NMI  Agent_1_avg_reward  \
# 0                  6.90             0.262618     0.000379              7.6165
# 1                  6.04             0.030680     0.002462              6.8929
# 2                  8.39             0.083098     0.000624              7.8849
# 3                  7.07             0.078804     0.540297              6.3031
# 4                  7.40             0.274232     0.000165              6.9612
#
#    Agent_1_final_reward
# 0                  7.69
# 1                  7.51
# 2                  8.08
# 3                  5.87
# 4                  7.27

# %% [markdown]
# ## Cannonical
#
# - World States: Two binary variables X, Y
# - agents_observed_variables = {0:[0],1:[1]}
# - Random Cannonical Games
# - n_features = 2
# - n_signaling_actions = 2
# - n_final_actions = 4

# %%
plot_all_histograms(df_cannonical_qlearn,bins=75)

# %%
plot_payoff_comparison(df_cannonical_qlearn)

# %% [markdown]
# ## General Games
#
# - World States: Three binary variables X, Y, Z
# - agents_observed_variables = {0:[0,1],1:[1,2]}
# - n_features = 3 #parameters['n_features']
# - n_signaling_actions = 4 #parameters['n_signaling_actions']
# - n_final_actions = 8 #parameters['n_final_actions']
# - Random Games (possibly non-cannonical)

# %%
plot_all_histograms(df_qlearn,bins=75)

# %%
plot_payoff_comparison(df_qlearn)

# %% [markdown]
# # Q-Learning initial_epsilon=1

# %% [markdown]
# ## Load Data

# %%
# Load DataFrame from a CSV file
df_cannonical_qlearn = pd.read_csv('basic_qlearning_results_cannonical_bigexplore.csv')
df_cannonical_qlearn.head(5)
# Out:
#    iteration  n_signaling_actions  n_final_actions  full_information  \
# 0          0                    2                4             False
# 1          0                    2                4             False
# 2          0                    2                4              True
# 3          0                    2                4              True
# 4          1                    2                4             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward  \
# 0         False             0.396390     0.000325              0.4980
# 1          True             0.107340     0.901415              0.4852
# 2         False             0.093474     0.000068              0.9840
# 3          True             0.425830     0.357803              0.9856
# 4         False             0.380881     0.000003              0.5015
#
#    Agent_0_final_reward  Agent_1_Initial_NMI  Agent_1_NMI  Agent_1_avg_reward  \
# 0                  0.55             0.015160     0.000051              0.5036
# 1                  0.49             0.045767     0.000024              0.9769
# 2                  1.00             0.129439     0.000012              0.9823
# 3                  1.00             0.095777     0.454289              0.9824
# 4                  0.42             0.044518     0.000009              0.5046
#
#    Agent_1_final_reward
# 0                  0.52
# 1                  1.00
# 2                  1.00
# 3                  1.00
# 4                  0.41

# %%
# Load DataFrame from a CSV file
df_qlearn = pd.read_csv('qlearning_results_bigexplore.csv')
df_qlearn.head(5)
# Out:
#    iteration  n_signaling_actions  n_final_actions  full_information  \
# 0          0                    4                8             False
# 1          0                    4                8             False
# 2          0                    4                8              True
# 3          0                    4                8              True
# 4          1                    4                8             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward  \
# 0         False             0.353922     0.000208              6.2198
# 1          True             0.702659     0.687672              7.3884
# 2         False             0.271198     0.000732              7.6873
# 3          True             0.284480     0.582416              7.5449
# 4         False             0.384328     0.000467              7.2990
#
#    Agent_0_final_reward  Agent_1_Initial_NMI  Agent_1_NMI  Agent_1_avg_reward  \
# 0                  6.22             0.629423     0.000234              8.2893
# 1                  7.23             0.588897     0.700743              8.0201
# 2                  7.79             0.412318     0.000352              8.7762
# 3                  7.66             0.597875     0.485124              8.3760
# 4                  7.28             0.552783     0.000225              7.6885
#
#    Agent_1_final_reward
# 0                  8.52
# 1                  8.27
# 2                  8.87
# 3                  8.51
# 4                  7.82

# %% [markdown]
# ## Cannonical
#
# - World States: Two binary variables X, Y
# - agents_observed_variables = {0:[0],1:[1]}
# - Random Cannonical Games
# - n_features = 2
# - n_signaling_actions = 2
# - n_final_actions = 4

# %%
plot_all_histograms(df_cannonical_qlearn,bins=75)

# %%
plot_payoff_comparison(df_cannonical_qlearn)

# %% [markdown]
# ## General Games
#
# - World States: Three binary variables X, Y, Z
# - agents_observed_variables = {0:[0,1],1:[1,2]}
# - n_features = 3 #parameters['n_features']
# - n_signaling_actions = 4 #parameters['n_signaling_actions']
# - n_final_actions = 8 #parameters['n_final_actions']
# - Random Games (possibly non-cannonical)

# %%
plot_all_histograms(df_qlearn,bins=75)

# %%
plot_payoff_comparison(df_qlearn)
