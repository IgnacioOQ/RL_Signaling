# %% [markdown]
# # Load Data

# %%
from imports import *
from utils import *
import seaborn as sns

# %%
# Load DataFrame from a CSV file
df_cannonical_urn = pd.read_csv('basic_urn_results_cannonical.csv')
df_cannonical_urn.head(5)
# Out:
#    iteration  n_signaling_actions  n_final_actions  full_information  \
# 0          0                    2                4             False
# 1          0                    2                4             False
# 2          0                    2                4              True
# 3          0                    2                4              True
# 4          0                    2                4             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward  \
# 0         False             0.043071     0.000007              0.4966
# 1          True             0.445669     0.259903              0.5610
# 2         False             0.204266     0.000024              0.9914
# 3          True             0.115715     0.131803              0.9782
# 4         False             0.099117     0.000033              0.5033
#
#    Agent_0_final_reward  Agent_1_Initial_NMI  Agent_1_NMI  Agent_1_avg_reward  \
# 0                  0.44             0.114866     0.000009              0.4997
# 1                  0.61             0.078832     0.038856              0.7731
# 2                  1.00             0.178605     0.000053              0.9887
# 3                  1.00             0.115116     0.052137              0.9829
# 4                  0.46             0.134844     0.000069              0.4962
#
#    Agent_1_final_reward
# 0                  0.50
# 1                  0.76
# 2                  1.00
# 3                  0.99
# 4                  0.61

# %%
# Load DataFrame from a CSV file
df_urn = pd.read_csv('urn_results.csv')
df_urn.head(5)
# Out:
#    iteration  n_signaling_actions  n_final_actions  full_information  \
# 0          0                    4                8             False
# 1          0                    4                8             False
# 2          0                    4                8              True
# 3          0                    4                8              True
# 4          0                    4                8             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward  \
# 0         False             0.328202     0.000145              5.2861
# 1          True             0.547447     0.550377              6.9115
# 2         False             0.728394     0.000343              7.8691
# 3          True             0.261849     0.336050              7.3133
# 4         False             0.497952     0.000596              5.7488
#
#    Agent_0_final_reward  Agent_1_Initial_NMI  Agent_1_NMI  Agent_1_avg_reward  \
# 0                  5.53             0.449555     0.000587              6.7910
# 1                  6.93             0.802967     0.486892              6.7822
# 2                  8.08             0.694683     0.000396              7.1386
# 3                  7.53             0.469551     0.325655              7.0651
# 4                  5.43             0.727333     0.000257              6.1938
#
#    Agent_1_final_reward
# 0                  7.13
# 1                  6.94
# 2                  7.45
# 3                  7.24
# 4                  6.38

# %% [markdown]
# # Cannonical
#
# - World States: Two binary variables X, Y
# - agents_observed_variables = {0:[0],1:[1]}
# - Random Cannonical Games
# - n_features = 2
# - n_signaling_actions = 2
# - n_final_actions = 4

# %%
plot_all_histograms(df_cannonical_urn,bins=75)

# %%
plot_payoff_comparison(df_cannonical_urn)

# %% [markdown]
# # General Urns
#
# - World States: Three binary variables X, Y, Z
# - agents_observed_variables = {0:[0,1],1:[1,2]}
# - n_features = 3 #parameters['n_features']
# - n_signaling_actions = 4 #parameters['n_signaling_actions']
# - n_final_actions = 8 #parameters['n_final_actions']
# - Random Games (possibly non-cannonical)

# %% [markdown]
# plot_all_histograms(df_urn,bins=75)

# %%
plot_payoff_comparison(df_urn)
