# %% [markdown]
# # Load Data

# %%
from imports import *
from utils import *
import seaborn as sns

# %%
# Load DataFrame from a CSV file
df_cannonical_urn = pd.read_csv('basic_urn_results_cannonical.csv')
df_cannonical_urn.head(5)
# Out:
#    iteration  n_signaling_actions  n_final_actions  full_information  \
# 0          0                    2                4             False
# 1          0                    2                4             False
# 2          0                    2                4              True
# 3          0                    2                4              True
# 4          1                    2                4             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward  \
# 0         False             0.037354     0.002289               0.505
# 1          True             0.046216     0.014548               0.521
# 2         False             0.121718     0.000411               0.920
# 3          True             0.136151     0.004060               0.878
# 4         False             0.175569     0.000153               0.471
#
#    Agent_0_final_reward  Agent_1_Initial_NMI  Agent_1_NMI  Agent_1_avg_reward  \
# 0                  0.51             0.089585     0.001606               0.478
# 1                  0.61             0.202778     0.016714               0.458
# 2                  0.98             0.337898     0.000390               0.940
# 3                  0.96             0.318738     0.124883               0.882
# 4                  0.51             0.041907     0.000221               0.454
#
#    Agent_1_final_reward
# 0                  0.44
# 1                  0.49
# 2                  0.98
# 3                  0.98
# 4                  0.49

# %%
# Load DataFrame from a CSV file
df_urn = pd.read_csv('urn_results.csv')
df_urn.head(5)
# Out:
#    iteration  n_signaling_actions  n_final_actions  full_information  \
# 0          0                    4                8             False
# 1          0                    4                8             False
# 2          0                    4                8              True
# 3          0                    4                8              True
# 4          1                    4                8             False
#
#    with_signals  Agent_0_Initial_NMI  Agent_0_NMI  Agent_0_avg_reward  \
# 0         False             0.247330     0.081680                4.45
# 1          True             0.440575     0.381169                4.76
# 2         False             0.446268     0.161164                6.34
# 3          True             0.308443     0.317902                4.95
# 4         False             0.550235     0.108703                5.41
#
#    Agent_0_final_reward  Agent_1_Initial_NMI  Agent_1_NMI  Agent_1_avg_reward  \
# 0                  4.45             0.521018     0.128548                4.63
# 1                  4.76             0.702620     0.591303                5.15
# 2                  6.34             0.784997     0.212379                5.49
# 3                  4.95             0.733517     0.423695                4.25
# 4                  5.41             0.562327     0.167259                4.10
#
#    Agent_1_final_reward
# 0                  4.63
# 1                  5.15
# 2                  5.49
# 3                  4.25
# 4                  4.10

# %% [markdown]
# # Cannonical
#
# - World States: Two binary variables X, Y
# - agents_observed_variables = {0:[0],1:[1]}
# - Random Cannonical Games
# - n_features = 2
# - n_signaling_actions = 2
# - n_final_actions = 4

# %%
plot_all_histograms(df_cannonical_urn,bins=75)

# %%
plot_payoff_comparison(df_cannonical_urn)

# %% [markdown]
# # General Urns
#
# - World States: Three binary variables X, Y, Z
# - agents_observed_variables = {0:[0,1],1:[1,2]}
# - n_features = 3 #parameters['n_features']
# - n_signaling_actions = 4 #parameters['n_signaling_actions']
# - n_final_actions = 8 #parameters['n_final_actions']
# - Random Games (possibly non-cannonical)

# %% [markdown]
# plot_all_histograms(df_urn,bins=75)

# %%
plot_payoff_comparison(df_urn)
